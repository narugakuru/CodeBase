# %%
name="python "
name1=name.rstrip()
name1
# Out:
# 'python'

# %%
import this
import timeit
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
bicycles = ['trek', 'cannondale', 'redline', 'specialized'] 
# print(bicycles[:])
for i in bicycles:
    print(i.title())
# Out:
# Trek
# Cannondale
# Redline
# Specialized

# %%
bicycles = ['trek', 'cannondale', 'redline', 'specialized'] 
bicycles.append("world")
del bicycles[0]
bicycles.insert(-1,"hello")
bicycles
# Out:
# ['cannondale', 'redline', 'specialized', 'hello', 'world']

# %%
laster = bicycles.pop(-1)
laster,bicycles
# Out:
# ('world', ['cannondale', 'redline', 'specialized', 'hello'])

# %%
bicycles = ['trek', 'cannondale', 'redline', 'specialized']
bicycles.remove('cannondale')
bicycles
# Out:
# ['trek', 'redline', 'specialized']

# %%
guest=['屑啦啦','小岚岚','小乌龟','小恐龙']
guest.remove('小恐龙')
guest.append('甜蜜蜜')
guest.insert(0,'dio')
guest
# Out:
# ['dio', '屑啦啦', '小岚岚', '小乌龟', '甜蜜蜜']

# %%
while(len(guest) > 2):
    print("delete:"+guest.pop())
print(guest)
# Out:
# delete:甜蜜蜜
# delete:小乌龟
# delete:小岚岚
# ['dio', '屑啦啦']

# %%
del guest[:]
guest
# Out:
# []

# %%
cars = ['bmw', 'audi', 'toyota', 'subaru']
sorted(cars)
# Out:
# ['audi', 'bmw', 'subaru', 'toyota']

# %%
cars.sort(reverse=True)
# cars.sort()
# cars.reverse()
cars
# Out:
# ['toyota', 'subaru', 'bmw', 'audi']

# %%
digits = [1, 2, 3, 4, 5, 6, 7, 8, 9, 0]
print(max(digits),sum(digits))
# Out:
# 9 45

# %%
squares = [value**2 for value in range(1,11)]
squares
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
sum100w=sum(range(1000000))
sum100w
# Out:
# 499999500000

# %%
s1='Three items from the middle of the list are'
s2=s1.split(' ')
s2
# Out:
# ['Three', 'items', 'from', 'the', 'middle', 'of', 'the', 'list', 'are']

# %%
def sum1():
    sum(range(1000000))
def sum2():
    res=0
    for i in range(1000000):
        res+=i
    return res
print ('For Loop Sum:', timeit.timeit(sum2, number=10))
print ('Built-in Sum:', timeit.timeit(sum1, number=10))
# Out:
# For Loop Sum: 0.32169769999999964
# Built-in Sum: 0.2086377000000006

# %%
requested_toppings = [] 
if requested_toppings: 
    for requested_topping in requested_toppings: 
        print("Adding " + requested_topping + ".") 
    print("\nFinished making your pizza!") 
else: 
    print("Are you sure you want a plain pizza?")
# Out:
# Are you sure you want a plain pizza?

# %%
alien_0 = {'color': 'green', 'points': 5}
alien_0['color']
del alien_0['points']
alien_0
# Out:
# {'color': 'green'}

# %%
favorite_languages = { 
 'jen': 'python', 
 'sarah': 'c', 
 'edward': 'ruby', 
 'phil': 'python', 
 } 
for name in favorite_languages.keys(): 
 print(name.title())
# Out:
# Jen
# Sarah
# Edward
# Phil

# %%
aliens=[]
for alien_number in range(30): 
    new_alien = {'color': 'green', 'points': 5, 'speed': 'slow'} 
    aliens.append(new_alien)

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
with open("data.txt", "r") as f:
    temp = f.readlines()
    print(temp)
# Out:
# ['\n', '===========================================\n', '招生单位： (10403)南昌大学 考试方式： 统考\n', '院系所： (006)数学与计算机学院 专业： (081200)计算机科学与技术\n', '学习方式： 全日制 研究方向： (01)机器学习与人工智能\n', '指导老师： 不区分导师 拟招人数： 专业：20(不含推免)\n', '备注： 推免生人数为上年度实际录取数，仅供参考，各专业招生计划以教育部最终下达为准，本计划不作为年度招生录取依据。\n', '考试范围\n', '政治 外语 业务课一 业务课二\n', '(101)思想政治理论\n', '见招生简章\n', '(201)英语（一）\n', '见招生简章\n', '(301)数学（一）\n', '见招生简章\n', '(408)计算机学科专业基础\n', '见招生简章\n', '===========================================\n', '招生单位： (10403)南昌大学 考试方式： 统考\n', '院系所： (006)数学与计算机学院 专业： (081200)计算机科学与技术\n', '学习方式： 全日制 研究方向： (02)图形图像处理与虚拟现实技术\n', '指导老师： 不区分导师 拟招人数： 专业：20(不含推免)\n', '备注： 推免生人数为上年度实际录取数，仅供参考，各专业招生计划以教育部最终下达为准，本计划不作为年度招生录取依据。\n', '考试范围\n', '政治 外语 业务课一 业务课二\n', '(101)思想政治理论\n', '见招生简章\n', '(201)英语（一）\n', '见招生简章\n', '(301)数学（一）\n', '见招生简章\n', '(408)计算机学科专业基础\n', '见招生简章\n', '===========================================\n', '招生单位： (10403)南昌大学 考试方式： 统考\n', '院系所： (006)数学与计算机学院 专业： (081200)计算机科学与技术\n', '学习方式： 全日制 研究方向： (03)计算机网络与信息安全\n', '指导老师： 不区分导师 拟招人数： 
# ...

# %%
file1 = open("data.txt", "r")
for i in file1:
    print(i)
# Out:
# ...
#
# 招生单位： (10403)南昌大学 考试方式： 统考
#
# 院系所： (006)数学与计算机学院 专业： (081200)计算机科学与技术
#
# 学习方式： 全日制 研究方向： (01)机器学习与人工智能
#
# 指导老师： 不区分导师 拟招人数： 专业：20(不含推免)
#
# 备注： 推免生人数为上年度实际录取数，仅供参考，各专业招生计划以教育部最终下达为准，本计划不作为年度招生录取依据。
#
# 考试范围
#
# 政治 外语 业务课一 业务课二
#
# (101)思想政治理论
#
# 见招生简章
#
# (201)英语（一）
#
# 见招生简章
#
# (301)数学（一）
#
# 见招生简章
#
# (408)计算机学科专业基础
#
# 见招生简章
#
# ...
#
# 招生单位： (10403)南昌大学 考试方式： 统考
#
# 院系所： (006)数学与计算机学院 专业： (081200)计算机科学与技术
#
# 学习方式： 全日制 研究方向： (02)图形图像处理与虚拟现实技术
#
# 指导老师： 不区分导师 拟招人数： 专业：20(不含推免)
#
# 备注： 推免生人数为上年度实际录取数，仅供参考，各专业招生计划以教育部最终下达为准，本计划不作为年度招生录取依据。
#
# 考试范围
#
# 政治 外语 业务课一 业务课二
#
# (101)思想政治理论
#
# 见招生简章
#
# (201)英语（一）
#
# 见招生简章
#
# (301)数学（一）
#
# 见招生简章
#
# (408)计算机学科专业基础
#
# 见招生简章
#
# ...
#
# 招生单位： (10403)南昌大学 考试方式： 统考
#
# 院系所： (006)数学与计算机学院 专业： (081200)计算机科学与技术
#
# 学习方式： 全日制 研究方向： (03)计算机网络与信息安全
#
# 指导老师： 不区分导师 拟招人数： 专业：20(不含推免)
#
# 备注： 推免生人数为上年度实际录取数，仅供参考，各专业招生计划以教育部最终下达为准，本计划不作为年度招生录取依据。
#
# 考试范围
#
# 政治 外语 业务课一 业务课二
#
# (101)思想政治理论
#
# 见招生简章
#
# (201)英语（一）
#
# 见招生简章
#
# (301)数学（一）
#
# 见招生简章
#
# ...

# %%
# 列表转字符串，写入文本
cars = ['bmw', 'audi', 'toyota', 'subaru']
with open("demo.txt",'w+') as demo_file:
    s1 = " ".join(cars[:])
    demo_file.write(s1)
    print(demo_file.readline())

# %%
#字典转字符串
import json

dict_data = {'name': 'Tom', 'age': 20}
str_data = json.dumps(dict_data)
print(str_data)  # 输出：{"name": "Tom", "age": 20}
# Out:
# {"name": "Tom", "age": 20}

# %%
dict_data = {'name': 'Tom', 'age': 20}
str_data = str(dict_data)
print(str_data)  # 输出：{'name': 'Tom', 'age': 20}
# Out:
# {'name': 'Tom', 'age': 20}

# %%
print("Give me two numbers, and I'll divide them.") 
print("Enter 'q' to quit.") 

while True: 
    first_number = input("\nFirst number: ") 
    if first_number == 'q': 
        break 
    second_number = input("Second number: ") 
    try: 
        answer = int(first_number) / int(second_number) 
    except ZeroDivisionError: 
        print("You can't divide by 0!") 
    else: 
        print(answer)

# %%
def count_words(filename): 
    """计算一个文件大致包含多少个单词""" 
    try: 
        with open(filename) as f_obj: 
            contents = f_obj.read() 
    except FileNotFoundError: 
        msg = "Sorry, the file " + filename + " does not exist." 
        print(msg) 
    else: 
        # 计算文件大致包含多少个单词
        words = contents.split() 
        num_words = len(words) 
        print("The file " + filename + " has about " + str(num_words) + 
        " words.")

# %%
count_words("data.txt")
# Out:
# The file data.txt has about 1002 words.

# %% [markdown]
# 10-6 加法运算：提示用户提供数值输入时，常出现的一个问题是，用户提供的是
# 文本而不是数字。在这种情况下，当你尝试将输入转换为整数时，将引发 TypeError 异
# 常。编写一个程序，提示用户输入两个数字，再将它们相加并打印结果。在用户输入的
# 任何一个值不是数字时都捕获 TypeError 异常，并打印一条友好的错误消息。对你编写
# 的程序进行测试：先输入两个数字，再输入一些文本而不是数字。
#
# 10-7 加法计算器：将你为完成练习 10-6 而编写的代码放在一个 while 循环中，让
# 用户犯错（输入的是文本而不是数字）后能够继续输入数字。
#
# 10-8 猫和狗：创建两个文件 cats.txt 和 dogs.txt，在第一个文件中至少存储三只猫的
# 名字，在第二个文件中至少存储三条狗的名字。编写一个程序，尝试读取这些文件，并
# 将其内容打印到屏幕上。将这些代码放在一个 try-except 代码块中，以便在文件不存
# 在时捕获 FileNotFound 错误，并打印一条友好的消息。将其中一个文件移到另一个地方，并确认 except 代码块中的代码将正确地执行。
#
# 10-9 沉默的猫和狗：修改你在练习 10-8 中编写的 except 代码块，让程序在文件不
# 存在时一言不发。
#
# 10-10 常见单词：访问项目 Gutenberg（http://gutenberg.org/），并找一些你想分析的
# 图书。下载这些作品的文本文件或将浏览器中的原始文本复制到文本文件中。
# 你可以使用方法 count()来确定特定的单词或短语在字符串中出现了多少次。例如，
# 下面的代码计算'row'在一个字符串中出现了多少次：
# ```python
# >>> line = "Row, row, row your boat"
# >>> line.count('row')
# 2
# >>> line.lower().count('row')
# 3
# ```
# 请注意，通过使用 lower()将字符串转换为小写，可捕捉要查找的单词出现的所有
# 次数，而不管其大小写格式如何。
# 编写一个程序，它读取你在项目 Gutenberg 中获取的文件，并计算单词'the'在每
# 个文件中分别出现了多少次。

# %%
# 加法运算
print("Give me two numbers, and I'll divide them.") 
print("Enter 'q' to quit.") 
while True:
    try:
        first_number = input("\nFirst number: ")
        if first_number == 'q':
            break
        second_number = input("Second number: ")
        if second_number == 'q': 
            break
        answer = int(first_number) + int(second_number)
        print(answer)
    except ValueError:
        print("请输入数字")
# Out:
# Give me two numbers, and I'll divide them.
# Enter 'q' to quit.
# 请输入数字
# 574
# 5

# %%
cats='date/cats.txt'
dogs='date/dog.txt'

def printTxt(path):
    try:
        with open(path,'r+')as f:
            print(f.readlines())
    except FileNotFoundError:
        print(path+'文件不存在')

printTxt(cats)
printTxt(dogs)
# Out:
# ['dio\n', 'borufu\n', 'narugakuru']
# date/dog.txt文件不存在

# %%
import json
numbers = [2, 3, 5, 7, 11, 13]
filename = 'date/numbers.json'

with open(filename, 'w') as f_obj:
    json.dump(numbers, f_obj)

# %%
filename = 'date/numbers.json'

with open(filename, 'r') as f_obj:
    numbers=json.load(f_obj)
print(numbers)
# Out:
# [2, 3, 5, 7, 11, 13]

# %%
# 如果以前存储了用户名，就加载它
# 否则，就提示用户输入用户名并存储它
filename = 'date/username.json'
try:
    with open(filename) as f_obj:
        username = json.load(f_obj)
except FileNotFoundError:
    username = input("What is your name? ")
    with open(filename, 'w') as f_obj:
        json.dump(username, f_obj)
        print("We'll remember you when you come back, " + username + "!")
else:
    print("Welcome back, " + username + "!")
# Out:
# Welcome back, raisei!

# %%
def get_stored_username():
    """如果存储了用户名，就获取它"""
    filename = 'date/username.json'
    try:
        with open(filename) as f_obj:
            username = json.load(f_obj)
    except FileNotFoundError:
        return None
    else:
        return username
    
def greet_user():
    """问候用户，并指出其名字"""
    username = get_stored_username()
    if username:
        print("Welcome back, " + username + "!")
    else:
        username = input("What is your name? ")
        filename = 'username.json'
        with open(filename, 'w') as f_obj:
            json.dump(username, f_obj)
            print("We'll remember you when you come back, " + username + "!")

greet_user()
# Out:
# Welcome back, raisei!

# %%
def get_stored_username():
    """如果存储了用户名，就获取它"""
    filename = 'date/username.json'
    try:
        with open(filename) as f_obj:
            username = json.load(f_obj)
    except FileNotFoundError:
        return None
    else:
        return username

def get_new_username():
    """提示用户输入用户名并存储"""
    username = input("What is your name? ")
    filename = 'username.json'
    with open(filename, 'w') as f_obj:
        json.dump(username, f_obj)
    return username

def greet_user():
    """问候用户，并指出其名字，或存储新用户"""
    username = get_stored_username()
    if username:
        print("Welcome back, " + username + "!")
    else:
        username = get_new_username()
        print("We'll remember you when you come back, " + username + "!")

greet_user()
# Out:
# Welcome back, raisei!
