# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\admin\Desktop\car.csv")

# %%
data
# Out:
#                       订单ID   用户手机号(假号码)                 设备ID  订单金额  实付金额  \
# 0     1283564608904503296'  18981942767  157829830668829372'  9.65  9.65
# 1     1283562046956511232'  18723348424  157829830668829372'  2.49  2.49
# 2     1283369878748930048'  18723348424  157829841525951628'  0.00  0.00
# 3     1283369044220846080'  18723348424  157829841525951628'  0.00  0.00
# 4     1283366330577461248'  13972829251  157829818607994096'  0.00  0.00
# ..                     ...          ...                  ...   ...   ...
# 916  15789908403790v4x2xp'  18872898390  157829841525951628'  6.00  6.00
# 917  15789001994763rye9ng'  18872898390  157829810475321301'  1.00  1.00
# 918  157889949935621u4h9w'  18872898390  157829810475321301'  0.00  0.00
# 919  15788986641561x72fcr'  18872898390  157829810475321301'  0.00  0.00
# 920  15787349138440x35gce'  15631584033  157829810475321301'  0.28  0.28
#
#      支付渠道  订单状态                订单时间
# 0    余额支付  订单成功  7/16/2020 08:50:25
# ...

# %%
data.groupby("设备ID")['订单金额'].agg(['min','max','std','count','sem'])
# Out:
#                      min    max       std  count       sem
# 设备ID
# 157829810475321301'  0.0  21.52  3.551002    232  0.233135
# 157829818607994096'  0.0  16.31  3.333888    138  0.283799
# 157829830668829372'  0.0  22.53  3.507112    267  0.214632
# 157829841525951628'  0.0  12.65  3.197926    284  0.189762

# %%
import math
def func(DF):
    return DF['std']/(float(math.sqrt(DF['count'])))

# %%
(data.groupby("设备ID")['订单金额'].agg(['std','count'])).apply(func,axis=1)
# Out:
# 设备ID
# 157829810475321301'    0.233135
# 157829818607994096'    0.283799
# 157829830668829372'    0.214632
# 157829841525951628'    0.189762
# dtype: float64

# %% [markdown]
# ---------

# %% [markdown]
# -----------------------

# %%
import pandas as pd

# %%
data = pd.read_csv(r"F:\1104635788从c盘剪贴过来的\car.csv")

# %%
data
# Out:
#                       订单ID   用户手机号(假号码)                 设备ID  订单金额  实付金额  \
# 0     1283564608904503296'  18981942767  157829830668829372'  9.65  9.65
# 1     1283562046956511232'  18723348424  157829830668829372'  2.49  2.49
# 2     1283369878748930048'  18723348424  157829841525951628'  0.00  0.00
# 3     1283369044220846080'  18723348424  157829841525951628'  0.00  0.00
# 4     1283366330577461248'  13972829251  157829818607994096'  0.00  0.00
# ..                     ...          ...                  ...   ...   ...
# 916  15789908403790v4x2xp'  18872898390  157829841525951628'  6.00  6.00
# 917  15789001994763rye9ng'  18872898390  157829810475321301'  1.00  1.00
# 918  157889949935621u4h9w'  18872898390  157829810475321301'  0.00  0.00
# 919  15788986641561x72fcr'  18872898390  157829810475321301'  0.00  0.00
# 920  15787349138440x35gce'  15631584033  157829810475321301'  0.28  0.28
#
#      支付渠道  订单状态                订单时间
# 0    余额支付  订单成功  7/16/2020 08:50:25
# ...

# %%
data['订单时间'] = data['订单时间'].apply(lambda x: x[0:x.index(" ")])  # 订单时间

# %%
data
# Out:
#                       订单ID   用户手机号(假号码)                 设备ID  订单金额  实付金额  \
# 0     1283564608904503296'  18981942767  157829830668829372'  9.65  9.65
# 1     1283562046956511232'  18723348424  157829830668829372'  2.49  2.49
# 2     1283369878748930048'  18723348424  157829841525951628'  0.00  0.00
# 3     1283369044220846080'  18723348424  157829841525951628'  0.00  0.00
# 4     1283366330577461248'  13972829251  157829818607994096'  0.00  0.00
# ..                     ...          ...                  ...   ...   ...
# 916  15789908403790v4x2xp'  18872898390  157829841525951628'  6.00  6.00
# 917  15789001994763rye9ng'  18872898390  157829810475321301'  1.00  1.00
# 918  157889949935621u4h9w'  18872898390  157829810475321301'  0.00  0.00
# 919  15788986641561x72fcr'  18872898390  157829810475321301'  0.00  0.00
# 920  15787349138440x35gce'  15631584033  157829810475321301'  0.28  0.28
#
#      支付渠道  订单状态       订单时间
# 0    余额支付  订单成功  7/16/2020
# 1    余额支付  订单成功  7/16/2020
# ...

# %%
data['订单时间'] = data['订单时间'].apply(lambda x: (x.split("/")[0] + "/" + x.split("/")[2]))  # 订单时间

# %%
str1 = "1/20/2020"
print(str1.split("/"))
print(str1.split("/"))
# Out:
# ['1', '20', '2020']
# ['1', '20', '2020']

# %%
data
# Out:
#                       订单ID   用户手机号(假号码)                 设备ID  订单金额  实付金额  \
# 0     1283564608904503296'  18981942767  157829830668829372'  9.65  9.65
# 1     1283562046956511232'  18723348424  157829830668829372'  2.49  2.49
# 2     1283369878748930048'  18723348424  157829841525951628'  0.00  0.00
# 3     1283369044220846080'  18723348424  157829841525951628'  0.00  0.00
# 4     1283366330577461248'  13972829251  157829818607994096'  0.00  0.00
# ..                     ...          ...                  ...   ...   ...
# 916  15789908403790v4x2xp'  18872898390  157829841525951628'  6.00  6.00
# 917  15789001994763rye9ng'  18872898390  157829810475321301'  1.00  1.00
# 918  157889949935621u4h9w'  18872898390  157829810475321301'  0.00  0.00
# 919  15788986641561x72fcr'  18872898390  157829810475321301'  0.00  0.00
# 920  15787349138440x35gce'  15631584033  157829810475321301'  0.28  0.28
#
#      支付渠道  订单状态    订单时间
# 0    余额支付  订单成功  7/2020
# 1    余额支付  订单成功  7/2020
# ...

# %%
pd.DataFrame({"数量统计":data.groupby("订单时间").count().sort_values(by="订单ID",ascending=False)['订单ID']})
# Out:
#         数量统计
# 订单时间
# 4/2020   276
# 5/2020   231
# 6/2020   205
# 1/2020    76
# 3/2020    61
# 7/2020    51
# 2/2020    21

# %% [markdown]
# # 到机器学习了

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import cross_val_score

# %%
X, y = load_breast_cancer(return_X_y=True, as_frame=True)

# %%
def train_cv():
    global X
    stds = StandardScaler()
    X = stds.fit_transform(X)
    cls = LogisticRegression(max_iter=10000)  # 逻辑回归
    cv = model_selection.cross_val_score(cls, X, y, cv=5, scoring="accuracy")
    return cv.mean()

# %%
import numpy as np
from sklearn.feature_selection import SelectKBest, chi2
k = 30
sa = np.zeros(k)
X_new = SelectKBest(chi2, k=22).fit_transform(X, y)  # 选择特征

# %%
from sklearn.preprocessing import StandardScaler
for i in range(k):
    # sa[i] = train()
    sa[i] = train_cv()
print(sa.mean(), sa.std())
# Out:
# nan nan

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler  # 标准化工具
from sklearn.feature_selection import SelectKBest, chi2 #特征选择
from sklearn.datasets import load_breast_cancer
from sklearn import model_selection

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


X, y = load_breast_cancer(return_X_y=True, as_frame=True) #加载乳腺癌数据
def train_cv():
    stds = StandardScaler() 
    x2 = stds.fit_transform(X)
    cls = LogisticRegression(max_iter=10000)  # 逻辑回归
    cv = model_selection.cross_val_score(cls, x2, y, cv=5, scoring="accuracy")
    return cv.mean()
k = 30
sa = np.zeros(k)
X_new = SelectKBest(chi2, k=22).fit_transform(X, y)  # 选择特征
for i in range(k):
    # sa[i] = train()
    sa[i] = train_cv()
print(sa.mean(), sa.std())
# Out:
# 0.9806862288464522 2.220446049250313e-16

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler  # 标准化工具
from sklearn.feature_selection import SelectKBest, chi2 #特征选择
from sklearn.datasets import load_breast_cancer
from sklearn import model_selection

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


X, y = load_breast_cancer(return_X_y=True, as_frame=True) #加载乳腺癌数据
def train_cv():
    stds = StandardScaler() 
    x2 = stds.fit_transform(X)
    cls = LogisticRegression(max_iter=10000)  # 逻辑回归
    cv = model_selection.cross_val_score(cls, x2, y, cv=8, scoring="accuracy")
    return cv.mean()
k = 30
sa = np.zeros(k)
X_new = SelectKBest(chi2, k=30).fit_transform(X, y)  # 选择特征
for i in range(k):
    # sa[i] = train()
    sa[i] = train_cv()
print(sa.mean(), sa.std())
# Out:
# 0.9806582550860722 1.1102230246251565e-16
